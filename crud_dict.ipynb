# %%
student = {}

name = input("Enter student name: ")
marks = int(input("Enter marks: "))

student["Name"] = name
student["Marks"] = marks

print("Student Dictionary:", student)
# Out:
# Enter student name:  keerthi
# Enter marks:  67
# Student Dictionary: {'Name': 'keerthi', 'Marks': 67}

# %%
fruits = {
    "Apple": 120,
    "Banana": 40,
    "Orange": 80,
    "Mango": 150,
    "Pineapple": 100
}

print("Fruit Dictionary:", fruits)
# Out:
# Fruit Dictionary: {'Apple': 120, 'Banana': 40, 'Orange': 80, 'Mango': 150, 'Pineapple': 100}

# %%
employees = {
    "Rahul": 50000,
    "Priyanka": 60000,
    "Amitha": 55000
}

name = input("Enter employee name: ")

if name in employees:
    print("Salary:", employees[name])
else:
    print("Employee not found")
# Out:
# Enter employee name:  Rahul
# Salary: 50000

# %%
countries = {
    "India": "New Delhi",
    "USA": "Washington D.C.",
    "Japan": "Tokyo",
    "France": "Paris"
}

for country, capital in countries.items():
    print(country, ":", capital)
# Out:
# India : New Delhi
# USA : Washington D.C.
# Japan : Tokyo
# France : Paris

# %%
student = {
    "Ravi": 75,
    "Anu": 85
}

name = input("Enter student name: ")

if name in student:
    new_marks = int(input("Enter new marks: "))
    student[name] = new_marks
    print("Updated Dictionary:", student)
else:
    print("Student not found")
# Out:
# Enter student name:  Anu
# Enter new marks:  98
# Updated Dictionary: {'Ravi': 75, 'Anu': 98}

# %%
inventory = {
    "Pen": 50,
    "Notebook": 30,
    "Pencil": 100
}

product = input("Enter product name: ")
amount = int(input("Enter quantity to add: "))

if product in inventory:
    inventory[product] += amount
    print("Updated Inventory:", inventory)
else:
    print("Product not found")
# Out:
# Enter product name:  Pen
# Enter quantity to add:  2
# Updated Inventory: {'Pen': 52, 'Notebook': 30, 'Pencil': 100}

# %%
student = {
    "Ravi kumar": 75,
    "Amitha": 85,
    "Kiran": 90
}

key = input("Enter key to delete: ")

if key in student:
    del student[key]
    print("Updated Dictionary:", student)
else:
    print("Key not found")
# Out:
# Enter key to delete:  Amitha
# Updated Dictionary: {'Ravi kumar': 75, 'Kiran': 90}

# %%
data = {
    "A": 1,
    "B": 2,
    "C": 3
}

data.clear()

print("Empty Dictionary:", data)
# Out:
# Empty Dictionary: {}
